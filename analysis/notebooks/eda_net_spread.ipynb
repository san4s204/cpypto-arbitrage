# %% [markdown]
# # %% 1. Импорт & подключение

# %%
import sys, pathlib
sys.path.append(str(pathlib.Path.cwd().parent))

# %%
import sys, pathlib
sys.path.append(str(pathlib.Path.cwd("D:\\Users\\79246\\Documents\\GitHub\\cpypto-arbitrage").parent))   # <─ добавили путь

import pandas as pd, sqlalchemy as sa, matplotlib.pyplot as plt
from src.db.session import engine
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 import sys, pathlib
# ----> 2 sys.path.append(str(pathlib.Path.cwd("D:\\Users\\79246\\Documents\\GitHub\\cpypto-arbitrage").parent))   # <─ добавили путь
#       4 import pandas as pd, sqlalchemy as sa, matplotlib.pyplot as plt
#       5 from src.db.session import engine
#
# TypeError: Path.cwd() takes 1 positional argument but 2 were given

# %%
df = pd.read_sql(sa.text("SELECT * FROM ohlcv_clean"), engine)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_sql(sa.text("SELECT * FROM ohlcv_clean"), engine)
#
# NameError: name 'engine' is not defined
